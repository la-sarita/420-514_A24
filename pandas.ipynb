# %% [markdown]
# <a href="https://colab.research.google.com/github/la-sarita/420-514_A24/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %%
import pandas as pd

s = pd.Series([1, 2, 3], index=["a", "b", "c"])
print(s)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35]}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
countries = ['France', 'Canada', 'Brésil', 'Australie', 'Inde', 'Chine', 'États-Unis', 'Russie', 'Mexique', 'Japon']
population = [67.39, 37.59, 211.05, 25.36, 1380, 1441, 331, 146.7, 126.2, 125.8]
area = [643801, 9984670, 8515767, 7692024, 3287263, 9596961, 9833517, 17098242, 1964375, 377975]

sc = pd.DataFrame({
    "Name": countries,
    "Pop": population,
    "Area": area
})

print(sc)
# Out:
#          Name      Pop      Area
# 0      France    67.39    643801
# 1      Canada    37.59   9984670
# 2      Brésil   211.05   8515767
# 3   Australie    25.36   7692024
# 4        Inde  1380.00   3287263
# 5       Chine  1441.00   9596961
# 6  États-Unis   331.00   9833517
# 7      Russie   146.70  17098242
# 8     Mexique   126.20   1964375
# 9       Japon   125.80    377975

# %%
sc
# Out:
#          Name      Pop      Area
# 0      France    67.39    643801
# 1      Canada    37.59   9984670
# 2      Brésil   211.05   8515767
# 3   Australie    25.36   7692024
# 4        Inde  1380.00   3287263
# 5       Chine  1441.00   9596961
# 6  États-Unis   331.00   9833517
# 7      Russie   146.70  17098242
# 8     Mexique   126.20   1964375
# 9       Japon   125.80    377975

# %%
# DataFrame avec le PIB de certains pays
gdp_data = {
    'Name': ['France', 'Canada', 'Brésil', 'Australie', 'Inde', 'États-Unis', 'Japon'],
    'GDP': [2715, 1643, 2055, 1393, 2875, 21433, 5065]  # PIB en milliards de dollars
}

df_gdp = pd.DataFrame(gdp_data)
df_gdp
# Out:
#          Name    GDP
# 0      France   2715
# 1      Canada   1643
# 2      Brésil   2055
# 3   Australie   1393
# 4        Inde   2875
# 5  États-Unis  21433
# 6       Japon   5065

# %%
# DataFrame avec les continents des pays
continent_data = {
    'Name': ['France', 'Canada', 'Brésil', 'Australie', 'Inde', 'Chine', 'États-Unis', 'Russie', 'Mexique', 'Japon'],
    'Continent': ['Europe', 'Amérique', 'Amérique', 'Océanie', 'Asie', 'Asie', 'Amérique', 'Europe', 'Amérique', 'Asie']
}

df_continent = pd.DataFrame(continent_data)
df_continent
# Out:
#          Name Continent
# 0      France    Europe
# 1      Canada  Amérique
# 2      Brésil  Amérique
# 3   Australie   Océanie
# 4        Inde      Asie
# 5       Chine      Asie
# 6  États-Unis  Amérique
# 7      Russie    Europe
# 8     Mexique  Amérique
# 9       Japon      Asie

# %%
df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
df['Age']  # Sélectionne la colonne 'Age'
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %%
df.Age  # Autre manière de sélectionner une colonne
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %%
df.to_json('data.json')  # Exporte le DataFrame vers un fichier JSON

# %%
df2 = pd.read_json('data.json')  # Charge un fichier JSON dans un DataFrame
df2
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
sc.to_csv('statCountry.csv')  # Exporter vers un fichier CSV
df3 = pd.read_csv('statCountry.csv')  # Charger un fichier CSV

# %%
df3
# Out:
#    Unnamed: 0        Name      Pop      Area
# 0           0      France    67.39    643801
# 1           1      Canada    37.59   9984670
# 2           2      Brésil   211.05   8515767
# 3           3   Australie    25.36   7692024
# 4           4        Inde  1380.00   3287263
# 5           5       Chine  1441.00   9596961
# 6           6  États-Unis   331.00   9833517
# 7           7      Russie   146.70  17098242
# 8           8     Mexique   126.20   1964375
# 9           9       Japon   125.80    377975

# %%
sc
# Out:
#          Name      Pop      Area
# 0      France    67.39    643801
# 1      Canada    37.59   9984670
# 2      Brésil   211.05   8515767
# 3   Australie    25.36   7692024
# 4        Inde  1380.00   3287263
# 5       Chine  1441.00   9596961
# 6  États-Unis   331.00   9833517
# 7      Russie   146.70  17098242
# 8     Mexique   126.20   1964375
# 9       Japon   125.80    377975

# %%
sc.describe()
# Out:
#                Pop          Area
# count    10.000000  1.000000e+01
# mean    389.209000  6.899460e+06
# std     545.692034  5.288620e+06
# min      25.360000  3.779750e+05
# 25%      81.992500  2.295097e+06
# 50%     136.450000  8.103896e+06
# 75%     301.012500  9.774378e+06
# max    1441.000000  1.709824e+07

# %%
sc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Pop     10 non-null     float64
#  2   Area    10 non-null     int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 368.0+ bytes

# %%
sc.head()
# Out:
#         Name      Pop     Area
# 0     France    67.39   643801
# 1     Canada    37.59  9984670
# 2     Brésil   211.05  8515767
# 3  Australie    25.36  7692024
# 4       Inde  1380.00  3287263

# %%
sc.head(10)
# Out:
#          Name      Pop      Area
# 0      France    67.39    643801
# 1      Canada    37.59   9984670
# 2      Brésil   211.05   8515767
# 3   Australie    25.36   7692024
# 4        Inde  1380.00   3287263
# 5       Chine  1441.00   9596961
# 6  États-Unis   331.00   9833517
# 7      Russie   146.70  17098242
# 8     Mexique   126.20   1964375
# 9       Japon   125.80    377975

# %%
df['Age'].plot(kind='bar')  # Crée un graphique en barres des âges
# Out:
# <Axes: >

# %%
sc.shape
# Out:
# (10, 3)

# %%
sc.columns
# Out:
# Index(['Name', 'Pop', 'Area'], dtype='object')

# %%
sc.dtypes
# Out:
# Name     object
# Pop     float64
# Area      int64
# dtype: object

# %%
sc.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
# Créer un DataFrame fictif
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
        'Age': [24, 42, 35, 23],
        'City': ['Paris', 'Londres', 'Paris', 'Berlin']}
df = pd.DataFrame(data)

# Filtrer les lignes où 'Age' est supérieur à 30
filtered_df = df[df['Age'] > 30]
print(filtered_df)

# Filtrer les lignes où 'City' est 'Paris'
paris_df = df[df['City'] == 'Paris']
print(paris_df)
# Out:
#       Name  Age     City
# 1      Bob   42  Londres
# 2  Charlie   35    Paris
#       Name  Age   City
# 0    Alice   24  Paris
# 2  Charlie   35  Paris

# %%
# Créer un DataFrame de ventes
sales_data = {'Product': ['A', 'B', 'C', 'D'],
              'Sales': [500, 700, 900, 1100],
              'Profit': [50, 80, 120, 160]}
df_sales = pd.DataFrame(sales_data)

# Résumé statistique des colonnes numériques
print(df_sales.describe())  # Moyenne, écart-type, min, max, etc.
# Out:
#             Sales      Profit
# count     4.00000    4.000000
# mean    800.00000  102.500000
# std     258.19889   47.871355
# min     500.00000   50.000000
# 25%     650.00000   72.500000
# 50%     800.00000  100.000000
# 75%     950.00000  130.000000
# max    1100.00000  160.000000

# %%
df_sales
# Out:
#   Product  Sales  Profit
# 0       A    500      50
# 1       B    700      80
# 2       C    900     120
# 3       D   1100     160

# %%
# Ajouter une nouvelle colonne 'Revenue' (ventes * profit)
df_sales['Revenue'] = df_sales['Sales'] * df_sales['Profit']
df_sales
# Out:
#   Product  Sales  Profit  Revenue
# 0       A    500      50    25000
# 1       B    700      80    56000
# 2       C    900     120   108000
# 3       D   1100     160   176000

# %%
# Supprimer la colonne 'Revenue'
df_sales.drop(columns=['Revenue'], inplace=True)
df_sales
# Out:
#   Product  Sales  Profit
# 0       A    500      50
# 1       B    700      80
# 2       C    900     120
# 3       D   1100     160

# %%
# Créer deux DataFrames
df1 = pd.DataFrame({'Employee': ['Alice', 'Bob'], 'Department': ['HR', 'Finance']})
df1
# Out:
#   Employee Department
# 0    Alice         HR
# 1      Bob    Finance

# %%
df2 = pd.DataFrame({'Employee': ['Alice', 'Bob'], 'Hire_Date': [2015, 2018]})
df2
# Out:
#   Employee  Hire_Date
# 0    Alice       2015
# 1      Bob       2018

# %%
# Faire une jointure sur la colonne 'Employee'
merged_df = pd.merge(df1, df2, on='Employee')
merged_df
# Out:
#   Employee Department  Hire_Date
# 0    Alice         HR       2015
# 1      Bob    Finance       2018

# %%
# Créer un DataFrame avec des ventes par produit
df = pd.DataFrame({'Product': ['A', 'B', 'A', 'B', 'A'],
                   'Sales': [500, 700, 600, 800, 400]})

df
# Out:
#   Product  Sales
# 0       A    500
# 1       B    700
# 2       A    600
# 3       B    800
# 4       A    400

# %%
# Grouper par 'Product' et calculer la somme des ventes
grouped_df = df.groupby('Product')['Sales'].sum()
grouped_df  # Somme des ventes par produit
# Out:
# Product
# A    1500
# B    1500
# Name: Sales, dtype: int64

# %%
# Créer une fonction pour augmenter les ventes de 10 %
def increase_sales(x):
    return x * 1.1

# Appliquer cette fonction sur la colonne 'Sales'
df['Increased_Sales'] = df['Sales'].apply(increase_sales)
df
# Out:
#   Product  Sales  Increased_Sales
# 0       A    500            550.0
# 1       B    700            770.0
# 2       A    600            660.0
# 3       B    800            880.0
# 4       A    400            440.0

# %%
# Appliquer cette fonction sur la colonne 'Sales'
df['Increased_Sales'] = df['Sales'].apply(lambda x : x * 1.1)
df
# Out:
#   Product  Sales  Increased_Sales
# 0       A    500            550.0
# 1       B    700            770.0
# 2       A    600            660.0
# 3       B    800            880.0
# 4       A    400            440.0

# %%
import numpy as np

# Créer un DataFrame fictif
data = {'A': [1, 2, 3, 4, 5], 'B': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)

# Utiliser NumPy pour calculer la moyenne
mean_A = np.mean(df['A'])
print("Moyenne de la colonne A :", mean_A)

df
# Out:
# Moyenne de la colonne A : 3.0
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
# 3  4  40
# 4  5  50

# %%
# Utiliser NumPy pour trouver les éléments où 'A' est supérieur à la moyenne
greater_than_mean = df['A'][df['A'] > mean_A]
greater_than_mean
# Out:
# 3    4
# 4    5
# Name: A, dtype: int64

# %%
sc[['Name', 'Pop']]
# Out:
#          Name      Pop
# 0      France    67.39
# 1      Canada    37.59
# 2      Brésil   211.05
# 3   Australie    25.36
# 4        Inde  1380.00
# 5       Chine  1441.00
# 6  États-Unis   331.00
# 7      Russie   146.70
# 8     Mexique   126.20
# 9       Japon   125.80

# %%
sc
# Out:
#          Name      Pop      Area
# 0      France    67.39    643801
# 1      Canada    37.59   9984670
# 2      Brésil   211.05   8515767
# 3   Australie    25.36   7692024
# 4        Inde  1380.00   3287263
# 5       Chine  1441.00   9596961
# 6  États-Unis   331.00   9833517
# 7      Russie   146.70  17098242
# 8     Mexique   126.20   1964375
# 9       Japon   125.80    377975

# %%
sc.iloc[0]
# Out:
# Name    France
# Pop      67.39
# Area    643801
# Name: 0, dtype: object

# %%
sc.loc[0]
# Out:
# Name    France
# Pop      67.39
# Area    643801
# Name: 0, dtype: object

# %%
sc['Pop'].sum()
# Out:
# 3892.0899999999997

# %%
sc['Area'].mean()  # Moyenne des superficies
# Out:
# 6899459.5

# %%
print(sc['Pop'].max())  # Population maximale
# Out:
# 1441.0

# %%
print(sc['Area'].min())  # Superficie minimale
# Out:
# 377975

# %%
sc['Pop'].median()  # Médiane de la population
# Out:
# 136.45

# %%
sc.sort_values(by='Area', ascending=False)
# Out:
#          Name      Pop      Area
# 7      Russie   146.70  17098242
# 1      Canada    37.59   9984670
# 6  États-Unis   331.00   9833517
# 5       Chine  1441.00   9596961
# 2      Brésil   211.05   8515767
# 3   Australie    25.36   7692024
# 4        Inde  1380.00   3287263
# 8     Mexique   126.20   1964375
# 0      France    67.39    643801
# 9       Japon   125.80    377975

# %%
# Convertir la colonne 'Pop' en tableau NumPy
pop_np = sc['Pop'].to_numpy()

# %%
pop_np
# Out:
# array([  67.39,   37.59,  211.05,   25.36, 1380.  , 1441.  ,  331.  ,
#         146.7 ,  126.2 ,  125.8 ])

# %%
# Multiplier la population par 1.05 (augmentation de 5%)
pop_np = pop_np * 1.05
pop_np
# Out:
# array([  70.7595,   39.4695,  221.6025,   26.628 , 1449.    , 1513.05  ,
#         347.55  ,  154.035 ,  132.51  ,  132.09  ])

# %%
print(np.std(pop_np))  # Écart-type
# Out:
# 295472.0027452725

# %%
print(np.var(pop_np))  # Variance
